# %%
import pandas as pd

## 1. Datos de entrada
# --- BLOQUE 1: DATAFRAME DE 7 EMPRESAS---
datos = {
    'nombre': ['Ferretería García','Bar El Rincón','Peluquería Ana','Tienda Moda Sol','Gestoría Pérez', 'Clínica Dental Martínez','Academia Idiomas Sol', 'Clínica Dental García','Academia de Idiomas English House'],
    'sector': ['Ferretería','Hostelería','Peluquería','Moda','Gestoría','Salud','Educación','Salud','Educación'],
    'facturacion': [320000, 180000, 95000, 210000, 140000, 280000,160000,295000,155000],
    'coste_ventas': [210000, 95000, 38000, 140000, 45000,84000,48000,118000,77500],
    'empleados': [5, 4, 2, 3, 3,6,5,6,5],
    'deuda': [45000, 12000, 8000, 35000, 5000,90000,15000,95000,14000],
    'activo_total': [180000, 85000, 40000, 120000, 70000,220000,75000,230000,72000],
    'año_fundacion': [2008, 2015, 2019, 2012, 2006,2014,2016,2013,2017]
}

df = pd.DataFrame(datos)
print(df)
print('\nNúmero de empresas analizadas:', len(df))

## 2. Cálculo de ratios
# --- BLOQUE 2: CÁLCULO DE RATIOS FINANCIEROS ---
# pandas calcula el ratio para TODAS las empresas a la vez con una sola línea
# es lo mismo que hacías con el diccionario pero para las 5 empresas simultáneamente

# Margen bruto en porcentaje
df['margen_bruto_pct'] = ((df['facturacion'] - df['coste_ventas']) / df['facturacion'] * 100).round(1)

# Ratio de endeudamiento (deuda / lo que tiene la empresa)
df['ratio_endeudamiento'] = (df['deuda'] / df['activo_total']).round(2)

# Facturación por empleado — eficiencia del negocio
df['fact_por_empleado'] = (df['facturacion'] / df['empleados']).round(0)

# Años que lleva abierta la empresa
df['años_activo'] = 2026 - df['año_fundacion']

# Ver la tabla con los nuevos ratios calculados
print(df[['nombre', 'margen_bruto_pct', 'ratio_endeudamiento', 'fact_por_empleado', 'años_activo']])

# --- BLOQUE 3: FILTROS DE INVERSIÓN ---
# Usamos los ratios calculados arriba para filtrar empresas
# df[condición] devuelve solo las filas donde la condición es True

# Empresas con bajo riesgo de deuda (menos del 30%)
bajo_riesgo = df[df['ratio_endeudamiento'] < 0.3]
print('Empresas con bajo endeudamiento:')
print(bajo_riesgo[['nombre', 'ratio_endeudamiento']])

# Empresas con buen margen Y bajo riesgo a la vez
# & significa que las dos condiciones tienen que cumplirse
candidatas = df[(df['margen_bruto_pct'] > 25) & (df['ratio_endeudamiento'] < 0.4)]
print('\nMejores candidatas para inversión:')
print(candidatas[['nombre', 'margen_bruto_pct', 'ratio_endeudamiento']])

# Ordenar todas las empresas por margen de mayor a menor
# ascending=False significa de mayor a menor
ranking = df.sort_values('margen_bruto_pct', ascending=False)
print('\nRanking por margen bruto:')
print(ranking[['nombre', 'margen_bruto_pct']])

# Empresas que están por encima de la media del grupo
media_margen = df['margen_bruto_pct'].mean()
sobre_media = df[df['margen_bruto_pct'] > media_margen]
print('\nEmpresas sobre la media del grupo:')
print(sobre_media['nombre'].tolist())

# --- BLOQUE 4: SCORING AUTOMÁTICO CON pd.cut() ---
# Versión mejorada del scoring de la Semana 1 — calcula para todas las empresas a la vez

# Scoring de endeudamiento
bins_deuda = [0, 0.25, 0.5, float('inf')]
labels_deuda = ['Bajo', 'Medio', 'Alto']
df['riesgo_deuda'] = pd.cut(df['ratio_endeudamiento'], bins=bins_deuda, labels=labels_deuda)

# Scoring de margen
bins_margen = [float('-inf'), 15, 30, float('inf')]
labels_margen = ['Bajo', 'Medio', 'Alto']
df['calidad_margen'] = pd.cut(df['margen_bruto_pct'], bins=bins_margen, labels=labels_margen)

# Puntuación numérica combinada
# Margen alto = 3 puntos, medio = 2, bajo = 1
# Deuda baja = 3 puntos, media = 2, alta = 1
# Más de 7 años activa = 2 puntos, menos = 1
mapa_margen = {'Bajo': 1, 'Medio': 2, 'Alto': 3}
mapa_deuda  = {'Bajo': 3, 'Medio': 2, 'Alto': 1}

df['puntos_margen']     = df['calidad_margen'].map(mapa_margen).astype(int)
df['puntos_deuda']      = df['riesgo_deuda'].map(mapa_deuda).astype(int)
df['puntos_antiguedad'] = df['años_activo'].apply(lambda x: 2 if x >= 7 else 1)
df['puntuacion_total']  = df['puntos_margen'] + df['puntos_deuda'] + df['puntos_antiguedad']

print(df[['nombre', 'calidad_margen', 'riesgo_deuda', 'años_activo', 'puntuacion_total']])

# --- BLOQUE 5: RANKING DE OPORTUNIDADES ---
# Ordenar todas las empresas por puntuación total de mayor a menor
# reset_index(drop=True) reinicia el índice desde 0 tras ordenar
ranking = df.sort_values('puntuacion_total', ascending=False).reset_index(drop=True)

# Empezar el índice en 1 en lugar de 0 — más legible como ranking
ranking.index = ranking.index + 1

# Columnas que aparecen en el ranking final
cols_ranking = ['nombre', 'sector', 'facturacion', 'margen_bruto_pct',
                'ratio_endeudamiento', 'años_activo', 'puntuacion_total',
                'calidad_margen', 'riesgo_deuda']

print('=' * 55)
print('RANKING DE OPORTUNIDADES DE INVERSIÓN EN PYMEs')
print('=' * 55)
print(ranking[cols_ranking].to_string())
print('\nMejor oportunidad:', ranking.iloc[0]['nombre'])
print('Mayor riesgo:     ', ranking.iloc[-1]['nombre'])


## 3. Estadística Descriptiva
# --- BLOQUE 6: RESUMEN ESTADÍSTICO Y AGRUPACIÓN ---

# describe() da un resumen estadístico completo de todas las columnas numéricas
# muestra mínimo, máximo, media, mediana y desviación estándar de golpe
print('=== RESUMEN ESTADÍSTICO ===')
print(df[['margen_bruto_pct', 'ratio_endeudamiento', 'fact_por_empleado']].describe())

# Media de cada ratio para todo el conjunto
# sirve para saber si una empresa está por encima o por debajo de la media del grupo
print('\n=== MEDIAS DEL GRUPO ===')
print('Margen bruto medio:', df['margen_bruto_pct'].mean().round(1), '%')
print('Endeudamiento medio:', df['ratio_endeudamiento'].mean().round(2))
print('Facturación por empleado media:', df['fact_por_empleado'].mean().round(0), '€')

# Qué empresa tiene el mejor y peor margen
# idxmax() devuelve el índice de la fila con el valor más alto
print('\n=== DESTACADOS ===')
print('Mejor margen:', df.loc[df['margen_bruto_pct'].idxmax(), 'nombre'])
print('Peor margen:', df.loc[df['margen_bruto_pct'].idxmin(), 'nombre'])
print('Menor riesgo de deuda:', df.loc[df['ratio_endeudamiento'].idxmin(), 'nombre'])

# groupby agrupa las filas por sector y calcula la media de cada grupo
# útil para comparar sectores entre sí — la base del análisis sectorial
print('\n=== MEDIAS POR SECTOR ===')
por_sector = df.groupby('sector')[['margen_bruto_pct', 'ratio_endeudamiento']].mean().round(2)
print(por_sector)
print('\nSectores ordenados por margen (mejor a peor):')
print(por_sector.sort_values('margen_bruto_pct', ascending=False))


# --- BLOQUE 7: RESUMEN DEL ANÁLISIS ---
# Resumen ejecutivo del notebook — lo que le mostrarías a un inversor
# en la primera página de un informe antes de que lea la tabla completa

print('=== ANALIZADOR DE PYMEs v0.1 — RESUMEN ===')

# Total de empresas en el DataFrame
print(f'Empresas analizadas: {len(df)}')

# Número de sectores distintos — nunique() cuenta valores únicos
print(f'Sectores cubiertos: {df["sector"].nunique()}')

# Mejor empresa — primera fila del ranking (mayor puntuación)
print(f'Mejor oportunidad: {ranking.iloc[0]["nombre"]} ({ranking.iloc[0]["puntuacion_total"]} puntos)')

# Peor empresa — última fila del ranking (menor puntuación)
print(f'Mayor riesgo: {ranking.iloc[-1]["nombre"]} ({ranking.iloc[-1]["puntuacion_total"]} puntos)')

# Margen bruto medio del conjunto
print(f'Margen bruto medio del grupo: {df["margen_bruto_pct"].mean().round(1)}%')

# Sector con mejor margen medio
print(f'Sector más rentable: {df.groupby("sector")["margen_bruto_pct"].mean().idxmax()}')


# --- BLOQUE 8: EXPORTACIÓN A EXCEL ---
# !pip install openpyxl -q

import openpyxl

nombre_archivo = 'ranking_pymes_v01.xlsx'

with pd.ExcelWriter(nombre_archivo, engine='openpyxl') as writer:

    # Hoja 1: Ranking completo ordenado por puntuación
    ranking[cols_ranking].to_excel(writer, sheet_name='Ranking', index=True)

    # Hoja 2: Datos originales con todos los ratios calculados
    df.to_excel(writer, sheet_name='Datos', index=False)

print(f'Archivo guardado: {nombre_archivo}')
print('Hojas: Ranking, Datos')

# --- BLOQUE 9: ESTADÍSTICA DESCRIPTIVA ---

print('=== RESUMEN ESTADÍSTICO DEL CONJUNTO ===')
print(df[['margen_bruto_pct','ratio_endeudamiento','fact_por_empleado','años_activo']].describe().round(2))

print('\n=== VALORES CLAVE ===')
print('Margen bruto medio:', df['margen_bruto_pct'].mean().round(1), '%')
print('Mediana de margen: ', round(df['margen_bruto_pct'].median(), 1), '%')
print('Desviación estándar:', round(df['margen_bruto_pct'].std(), 1), '%')

# Detectar outliers — empresas más de 1.5 desviaciones de la media
media   = df['margen_bruto_pct'].mean()
std_dev = df['margen_bruto_pct'].std()
outliers = df[abs(df['margen_bruto_pct'] - media) > 1.5 * std_dev]
print('\nOutliers por margen bruto:')
print(outliers[['nombre', 'margen_bruto_pct']])

## 4. Análisis de correlaciones
# --- BLOQUE 10: MATRIZ DE CORRELACIONES ---

columnas_num = ['facturacion', 'margen_bruto_pct', 'ratio_endeudamiento',
                'fact_por_empleado', 'años_activo', 'puntuacion_total']

correlacion = df[columnas_num].corr().round(2)
print('=== MATRIZ DE CORRELACIÓN ===')
print(correlacion)

print('\nCorrelación de cada variable con la puntuación total:')
print(correlacion['puntuacion_total'].sort_values(ascending=False))

for col in columnas_num:
    val = correlacion.loc[col, 'puntuacion_total']
    if col != 'puntuacion_total' and abs(val) > 0.5:
        direccion = 'positiva' if val > 0 else 'negativa'
        print(f'{col} tiene correlación {direccion} fuerte con puntuación: {val}')

## 5. Análisis estadístico por sector
# --- BLOQUE 11: ANÁLISIS ESTADÍSTICO POR SECTOR ---

stats_sector = df.groupby('sector')['margen_bruto_pct'].agg(
    media='mean',
    mediana='median',
    desviacion='std',
    minimo='min',
    maximo='max',
    empresas='count'
).round(2)

print('=== ANÁLISIS ESTADÍSTICO POR SECTOR ===')
print(stats_sector)

print('\nSectores ordenados por margen medio:')
print(stats_sector.sort_values('media', ascending=False))

print('\nSectores por variabilidad (std):')
print(stats_sector[['desviacion']].sort_values('desviacion', ascending=False))

## 6. Scoring estadístico por percentiles
# --- BLOQUE 12: SCORING POR PERCENTILES ---

# Para margen: más es mejor
df['pct_margen'] = df['margen_bruto_pct'].rank(pct=True).round(2)

# Para endeudamiento: menos es mejor — rank invertido
df['pct_deuda'] = (1 - df['ratio_endeudamiento'].rank(pct=True)).round(2)

# Para antigüedad: más es mejor
df['pct_antiguedad'] = df['años_activo'].rank(pct=True).round(2)

# Pesos: margen 50%, deuda 30%, antigüedad 20%
df['score_estadistico'] = (
    df['pct_margen']     * 0.50 +
    df['pct_deuda']      * 0.30 +
    df['pct_antiguedad'] * 0.20
).round(3)

ranking_v2 = df.sort_values('score_estadistico', ascending=False).reset_index(drop=True)
ranking_v2.index = ranking_v2.index + 1

print('=== RANKING v0.2 — SCORING ESTADÍSTICO ===')
print(ranking_v2[['nombre', 'pct_margen', 'pct_deuda', 'pct_antiguedad', 'score_estadistico']])
print('\nMejor oportunidad:', ranking_v2.iloc[0]['nombre'])

## 7. Ranking final v0.2
# --- BLOQUE 13: RANKING v0.2 ---

print('=' * 55)
print('RANKING v0.2 — SCORING ESTADÍSTICO POR PERCENTILES')
print('=' * 55)

cols_ranking_v2 = ['nombre', 'sector', 'pct_margen', 'pct_deuda',
                   'pct_antiguedad', 'score_estadistico']

print(ranking_v2[cols_ranking_v2].to_string())
print('\nMejor oportunidad:', ranking_v2.iloc[0]['nombre'],
      '— score:', ranking_v2.iloc[0]['score_estadistico'])
print('Mayor riesgo:     ', ranking_v2.iloc[-1]['nombre'],
      '— score:', ranking_v2.iloc[-1]['score_estadistico'])

# --- BLOQUE 14: RESUMEN FINAL v0.2 ---

print('==== ANALIZADOR DE PYMEs v0.2 — RESUMEN ====')
print(f'Empresas analizadas: {len(df)}')
print(f'Sectores cubiertos: {df["sector"].nunique()}')
print(f'Correlación margen-score: {round(df["margen_bruto_pct"].corr(df["score_estadistico"]), 2)}')
print(f'Mejor oportunidad: {ranking_v2.iloc[0]["nombre"]} (score: {ranking_v2.iloc[0]["score_estadistico"]})')
print(f'Mayor riesgo: {ranking_v2.iloc[-1]["nombre"]} (score: {ranking_v2.iloc[-1]["score_estadistico"]})')
print(f'Sector con mejor margen medio: {stats_sector["media"].idxmax()}')

## 8. Visualización — Gráfico de barras del ranking
# --- BLOQUE 15: GRÁFICO DE BARRAS DEL RANKING ---
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Colores según nivel de riesgo de deuda
colores = []
for _, row in ranking_v2.iterrows():
    if row['riesgo_deuda'] == 'Bajo':
        colores.append('#16a34a')    # verde
    elif row['riesgo_deuda'] == 'Medio':
        colores.append('#d97706')    # naranja
    else:
        colores.append('#dc2626')    # rojo

# Crear el gráfico
fig, ax = plt.subplots(figsize=(12, 6))

bars = ax.barh(ranking_v2['nombre'], ranking_v2['score_estadistico'],
               color=colores, edgecolor='white', linewidth=0.5)

# Etiqueta con el score al lado de cada barra
for bar, score in zip(bars, ranking_v2['score_estadistico']):
    ax.text(bar.get_width() + 0.01, bar.get_y() + bar.get_height() / 2,
            f'{score:.3f}', va='center', fontsize=9)

ax.set_xlabel('Score estadístico (0-1)', fontsize=11)
ax.set_title('Ranking de Oportunidades de Inversión en PYMEs', fontsize=13, fontweight='bold')
ax.set_xlim(0, 1.1)
ax.invert_yaxis()

leyenda = [mpatches.Patch(color='#16a34a', label='Riesgo Bajo'),
           mpatches.Patch(color='#d97706', label='Riesgo Medio'),
           mpatches.Patch(color='#dc2626', label='Riesgo Alto')]
ax.legend(handles=leyenda, loc='lower right')
ax.grid(True, alpha=0.3, axis='x')
plt.tight_layout()
plt.savefig('grafico_ranking_pymes.png', dpi=150, bbox_inches='tight')
plt.show()
print('Gráfico guardado como grafico_ranking_pymes.png')

## 9. Visualización — Scatter plot margen vs deuda
# --- BLOQUE 16: SCATTER PLOT MARGEN VS DEUDA ---

fig, ax = plt.subplots(figsize=(11, 7))

# Tamaño del punto proporcional a la facturación
sizes = ((df['facturacion'] - df['facturacion'].min()) /
         (df['facturacion'].max() - df['facturacion'].min()) * 500 + 100)

scatter = ax.scatter(
    df['ratio_endeudamiento'],
    df['margen_bruto_pct'],
    s=sizes,
    c=df['score_estadistico'],
    cmap='RdYlGn',
    alpha=0.8,
    edgecolors='gray',
    linewidth=0.5
)

# Etiqueta con el nombre de cada empresa
for _, row in df.iterrows():
    ax.annotate(row['nombre'].split(' ')[0],
                (row['ratio_endeudamiento'], row['margen_bruto_pct']),
                textcoords='offset points', xytext=(6, 4), fontsize=8)

# Líneas de referencia en la media del conjunto
ax.axvline(x=df['ratio_endeudamiento'].mean(), color='gray',
           linestyle='--', alpha=0.5, label='Deuda media')
ax.axhline(y=df['margen_bruto_pct'].mean(), color='gray',
           linestyle='--', alpha=0.5, label='Margen medio')

plt.colorbar(scatter, ax=ax, label='Score estadístico')
ax.set_xlabel('Ratio de endeudamiento', fontsize=11)
ax.set_ylabel('Margen bruto (%)', fontsize=11)
ax.set_title('Margen vs Riesgo de Deuda — Mapa de oportunidades',
             fontsize=13, fontweight='bold')
ax.legend(fontsize=9)
ax.grid(True, alpha=0.2)
plt.tight_layout()
plt.savefig('scatter_margen_deuda.png', dpi=150, bbox_inches='tight')
plt.show()
print('Gráfico guardado como scatter_margen_deuda.png')

## 10. Visualización — Histogramas de distribución
# --- BLOQUE 17: PANEL DE HISTOGRAMAS DE DISTRIBUCIÓN ---

fig, axes = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Distribución de Variables Financieras — 9 PYMEs',
             fontsize=14, fontweight='bold')

variables = [
    ('margen_bruto_pct',    'Margen bruto (%)',          'steelblue'),
    ('ratio_endeudamiento', 'Ratio de endeudamiento',    'darkorange'),
    ('fact_por_empleado',   'Facturación/empleado (€)',  'green'),
    ('años_activo',         'Años en activo',            'purple'),
]

for ax, (col, titulo, color) in zip(axes.flat, variables):
    ax.hist(df[col], bins=5, color=color, edgecolor='white',
            alpha=0.85, linewidth=0.8)
    ax.axvline(df[col].mean(), color='red', linestyle='--',
               linewidth=1.5, label=f'Media: {df[col].mean():.1f}')
    ax.axvline(df[col].median(), color='navy', linestyle=':',
               linewidth=1.5, label=f'Mediana: {df[col].median():.1f}')
    ax.set_title(titulo, fontsize=11, fontweight='bold')
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.2, axis='y')

plt.tight_layout()
plt.savefig('histogramas_pymes.png', dpi=150, bbox_inches='tight')
plt.show()
print('✅ Histogramas guardados como histogramas_pymes.png')

## 11. Visualización — Comparativa por sector
# --- BLOQUE 18: COMPARATIVA SECTORIAL VISUAL ---

import numpy as np

# --- DATOS AGRUPADOS POR SECTOR ---
resumen_sector = df.groupby('sector').agg(
    margen_medio=('margen_bruto_pct', 'mean'),
    deuda_media=('ratio_endeudamiento', 'mean'),
    score_medio=('score_estadistico', 'mean'),
    n_empresas=('nombre', 'count')
).round(2).reset_index()

resumen_sector = resumen_sector.sort_values('score_medio', ascending=False)

# --- GRÁFICO DE BARRAS AGRUPADAS ---
x = np.arange(len(resumen_sector))
ancho = 0.25

fig, ax = plt.subplots(figsize=(13, 7))

bars1 = ax.bar(x - ancho, resumen_sector['margen_medio'],
               ancho, label='Margen bruto medio (%)', color='steelblue', alpha=0.85)
bars2 = ax.bar(x, resumen_sector['deuda_media'] * 100,
               ancho, label='Endeudamiento medio (%)', color='darkorange', alpha=0.85)
bars3 = ax.bar(x + ancho, resumen_sector['score_medio'] * 100,
               ancho, label='Score estadístico (x100)', color='green', alpha=0.85)

ax.set_xlabel('Sector', fontsize=11)
ax.set_ylabel('Valor', fontsize=11)
ax.set_title('Comparativa por Sector — Margen, Deuda y Score',
             fontsize=13, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(resumen_sector['sector'], rotation=30, ha='right', fontsize=9)
ax.legend(fontsize=9)
ax.grid(True, alpha=0.2, axis='y')
plt.tight_layout()
plt.savefig('comparativa_sectorial.png', dpi=150, bbox_inches='tight')
plt.show()
print('✅ Gráfico guardado como comparativa_sectorial.png')

## 12. Visualización — Dashboard completo 2x2
# --- BLOQUE 19: DASHBOARD COMPLETO 2x2 ---

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('Dashboard — Analizador de PYMEs v0.2',
             fontsize=16, fontweight='bold', y=1.02)

# --- PANEL 1: Ranking de barras ---
ax1.barh(ranking_v2['nombre'], ranking_v2['score_estadistico'],
         color=['#16a34a' if r == 'Bajo' else '#d97706' if r == 'Medio' else '#dc2626'
                for r in ranking_v2['riesgo_deuda']])
ax1.set_title('Ranking de oportunidades', fontweight='bold')
ax1.invert_yaxis()
ax1.set_xlim(0, 1.0)
ax1.grid(True, alpha=0.3, axis='x')

# --- PANEL 2: Scatter margen vs deuda ---
sizes2 = ((df['facturacion'] - df['facturacion'].min()) /
          (df['facturacion'].max() - df['facturacion'].min()) * 300 + 80)
ax2.scatter(df['ratio_endeudamiento'], df['margen_bruto_pct'],
            s=sizes2, c=df['score_estadistico'], cmap='RdYlGn', alpha=0.85)
for _, row in df.iterrows():
    ax2.annotate(row['nombre'].split(' ')[0],
                 (row['ratio_endeudamiento'], row['margen_bruto_pct']),
                 fontsize=7, xytext=(4, 3), textcoords='offset points')
ax2.axvline(df['ratio_endeudamiento'].mean(), color='gray', linestyle='--', alpha=0.5)
ax2.axhline(df['margen_bruto_pct'].mean(), color='gray', linestyle='--', alpha=0.5)
ax2.set_xlabel('Ratio deuda')
ax2.set_ylabel('Margen bruto (%)')
ax2.set_title('Margen vs Deuda', fontweight='bold')
ax2.grid(True, alpha=0.2)

# --- PANEL 3: Histograma de márgenes ---
ax3.hist(df['margen_bruto_pct'], bins=5, color='steelblue',
         edgecolor='white', alpha=0.85)
ax3.axvline(df['margen_bruto_pct'].mean(), color='red', linestyle='--',
            label=f'Media {df["margen_bruto_pct"].mean():.1f}%')
ax3.set_title('Distribución del margen bruto', fontweight='bold')
ax3.set_xlabel('Margen bruto (%)')
ax3.legend(fontsize=8)
ax3.grid(True, alpha=0.2, axis='y')

# --- PANEL 4: Score medio por sector ---
score_x_sector = df.groupby('sector')['score_estadistico'].mean().sort_values(ascending=False)
score_x_sector.plot(kind='bar', ax=ax4, color='green', alpha=0.8, edgecolor='white')
ax4.set_title('Score medio por sector', fontweight='bold')
ax4.set_xlabel('')
ax4.tick_params(axis='x', rotation=30)
ax4.grid(True, alpha=0.2, axis='y')

plt.tight_layout()
plt.savefig('dashboard_pymes_v02.png', dpi=150, bbox_inches='tight')
plt.show()
print('✅ Dashboard guardado como dashboard_pymes_v02.png')

## 13. Visualización Plotly — Ranking interactivo
# --- BLOQUE 20: RANKING INTERACTIVO CON PLOTLY ---

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.default = 'iframe'

fig = px.bar(
    ranking_v2,
    x='score_estadistico',
    y='nombre',
    orientation='h',
    color='riesgo_deuda',
    color_discrete_map={'Bajo': '#16a34a', 'Medio': '#d97706', 'Alto': '#dc2626'},
    hover_data=['margen_bruto_pct', 'ratio_endeudamiento', 'años_activo'],
    title='Ranking de Oportunidades — Analizador de PYMEs v0.2',
    labels={
        'score_estadistico': 'Score estadístico',
        'nombre': 'Empresa',
        'riesgo_deuda': 'Riesgo de deuda'
    }
)

fig.update_yaxes(autorange='reversed')
fig.update_layout(height=500, showlegend=True)

fig.write_html('ranking_interactivo.html')
print('✅ Gráfico guardado como ranking_interactivo.html')
print('   Ábrelo desde el panel Output de Kaggle para verlo interactivo')

## 14. Visualización Plotly — Scatter interactivo
# --- BLOQUE 21: SCATTER INTERACTIVO CON PLOTLY ---

fig_scatter = px.scatter(
    df,
    x='ratio_endeudamiento',
    y='margen_bruto_pct',
    size='facturacion',
    color='sector',
    text='nombre',
    hover_data={
        'facturacion': True,
        'empleados': True,
        'años_activo': True,
        'score_estadistico': True,
        'puntuacion_total': True
    },
    title='Mapa de Oportunidades — Margen vs Riesgo de Deuda',
    labels={
        'ratio_endeudamiento': 'Ratio de endeudamiento',
        'margen_bruto_pct': 'Margen bruto (%)',
        'sector': 'Sector'
    },
    size_max=50
)

fig_scatter.add_hline(y=df['margen_bruto_pct'].mean(),
                      line_dash='dot', line_color='gray',
                      annotation_text='Margen medio')
fig_scatter.add_vline(x=df['ratio_endeudamiento'].mean(),
                      line_dash='dot', line_color='gray',
                      annotation_text='Deuda media')

fig_scatter.update_traces(textposition='top center', textfont_size=9)
fig_scatter.update_layout(height=550)

fig_scatter.write_html('scatter_interactivo.html')
print('✅ Gráfico guardado como scatter_interactivo.html')
print('   Ábrelo desde el panel Output de Kaggle para verlo interactivo')

## 15. Visualización Plotly — Radar de perfil financiero
# --- BLOQUE 22: RADAR DE PERFIL FINANCIERO ---

# --- NORMALIZAR VARIABLES PARA EL RADAR (0 a 1) ---
def normalizar(serie):
    return (serie - serie.min()) / (serie.max() - serie.min())

df['n_margen']     = normalizar(df['margen_bruto_pct'])
df['n_deuda']      = 1 - normalizar(df['ratio_endeudamiento'])
df['n_eficiencia'] = normalizar(df['fact_por_empleado'])
df['n_antiguedad'] = normalizar(df['años_activo'])
df['n_score']      = normalizar(df['score_estadistico'])

# --- RADAR PARA LAS 2 MEJORES EMPRESAS ---
categorias = ['Margen', 'Solvencia', 'Eficiencia', 'Antigüedad', 'Score']
empresa1 = ranking_v2.iloc[0]['nombre']
empresa2 = ranking_v2.iloc[1]['nombre']

def valores_radar(nombre):
    row = df[df['nombre'] == nombre].iloc[0]
    return [row['n_margen'], row['n_deuda'], row['n_eficiencia'],
            row['n_antiguedad'], row['n_score']]

fig_radar = go.Figure()

fig_radar.add_trace(go.Scatterpolar(
    r=valores_radar(empresa1),
    theta=categorias,
    fill='toself',
    name=empresa1,
    opacity=0.7
))

fig_radar.add_trace(go.Scatterpolar(
    r=valores_radar(empresa2),
    theta=categorias,
    fill='toself',
    name=empresa2,
    opacity=0.7
))

fig_radar.update_layout(
    polar=dict(radialaxis=dict(visible=True, range=[0, 1])),
    showlegend=True,
    title=f'Perfil Financiero — {empresa1} vs {empresa2}',
    height=500
)

fig_radar.write_html('radar_empresas.html')
print('✅ Gráfico guardado como radar_empresas.html')
print(f'   Comparando: {empresa1} vs {empresa2}')

## 16. Visualización Plotly — Dashboard interactivo
# --- BLOQUE 23: DASHBOARD INTERACTIVO CON PLOTLY SUBPLOTS ---

fig_dashboard = make_subplots(
    rows=1, cols=2,
    subplot_titles=('Ranking de Oportunidades', 'Mapa Margen vs Deuda'),
    column_widths=[0.45, 0.55]
)

# --- PANEL IZQUIERDO: ranking de barras por nivel de riesgo ---
colores_risk = {'Bajo': '#16a34a', 'Medio': '#d97706', 'Alto': '#dc2626'}

for risk_level, group in ranking_v2.groupby('riesgo_deuda'):
    fig_dashboard.add_trace(
        go.Bar(
            y=group['nombre'],
            x=group['score_estadistico'],
            orientation='h',
            name=f'Riesgo {risk_level}',
            marker_color=colores_risk[risk_level],
            hovertemplate='<b>%{y}</b><br>Score: %{x:.3f}<extra></extra>'
        ),
        row=1, col=1
    )

# --- PANEL DERECHO: scatter margen vs deuda ---
fig_dashboard.add_trace(
    go.Scatter(
        x=df['ratio_endeudamiento'],
        y=df['margen_bruto_pct'],
        mode='markers+text',
        text=df['nombre'].str.split(' ').str[0],
        textposition='top center',
        marker=dict(
            size=12,
            color=df['score_estadistico'],
            colorscale='RdYlGn',
            showscale=True
        ),
        hovertemplate='<b>%{text}</b><br>Deuda: %{x:.2f}<br>Margen: %{y:.1f}%<extra></extra>',
        showlegend=False
    ),
    row=1, col=2
)

fig_dashboard.update_layout(
    title_text='Dashboard — Analizador de PYMEs v0.2',
    height=550,
    showlegend=True
)
fig_dashboard.update_yaxes(autorange='reversed', row=1, col=1)

fig_dashboard.write_html('dashboard_interactivo.html')
print('✅ Dashboard guardado como dashboard_interactivo.html')
print('   Ábrelo desde el panel Output de Kaggle para verlo interactivo')

## 17. Comparativa sectorial — Descarga de cotizadas
# --- BLOQUE 24: DESCARGA DE DATOS FUNDAMENTALES DE COTIZADAS ---

import yfinance as yf

# Tickers comparables por sector con las PYMEs del Analizador
tickers_comparables = {
    'MCD':    'Hostelería',
    'ITX.MC': 'Moda',
    'FRE.DE': 'Salud',
    'PSO':    'Educación',
    'FAST':   'Ferretería',
    'HRB':    'Gestoría'
}

datos_cotizadas = []

for ticker, sector in tickers_comparables.items():
    try:
        info = yf.Ticker(ticker).info
        datos_cotizadas.append({
            'nombre':          info.get('shortName', ticker),
            'ticker':          ticker,
            'sector':          sector,
            'margen_bruto_pct': round(info.get('grossMargins', 0) * 100, 1),
            'margen_operativo': round(info.get('operatingMargins', 0) * 100, 1),
            'per':              round(info.get('trailingPE', 0), 1),
            'tipo':            'Cotizada'
        })
        print(f'✓ {ticker} descargado')
    except Exception as e:
        print(f'✗ {ticker} — error: {e}')

df_cotizadas = pd.DataFrame(datos_cotizadas)

print('\nDatos de cotizadas:')
print(df_cotizadas[['nombre', 'sector', 'margen_bruto_pct',
                     'margen_operativo', 'per']])

## 18. Comparativa sectorial — Fusión PYMEs y cotizadas
# --- BLOQUE 25: FUSIÓN DE PYMEs Y COTIZADAS EN UN SOLO DATAFRAME ---

# --- PREPARAR EL DATAFRAME DE PYMEs ---
df_pymes = df[['nombre', 'sector', 'margen_bruto_pct',
               'ratio_endeudamiento']].copy()
df_pymes['tipo'] = 'PYME'
df_pymes['margen_operativo'] = (df['margen_bruto_pct'] * 0.6).round(1)
df_pymes['per'] = None

# --- PREPARAR EL DATAFRAME DE COTIZADAS ---
df_comp = df_cotizadas[['nombre', 'sector', 'margen_bruto_pct',
                         'margen_operativo', 'per', 'tipo']].copy()
df_comp['ratio_endeudamiento'] = None

# --- MERGE VERTICAL ---
df_total = pd.concat([df_pymes, df_comp], ignore_index=True)

print('DataFrame combinado:')
print(df_total.groupby(['sector', 'tipo']).size().reset_index(
    name='n_empresas'))

# --- COMPARATIVA NUMÉRICA POR SECTOR ---
comparativa = df_total.groupby(
    ['sector', 'tipo'])['margen_bruto_pct'].mean().round(1)
comparativa = comparativa.reset_index()
comparativa.columns = ['sector', 'tipo', 'margen_medio']

print('\nMargen bruto medio — PYMEs vs cotizadas:')
print(comparativa.pivot(index='sector', columns='tipo',
                        values='margen_medio'))

## 19. Comparativa sectorial — Gráfico PYMEs vs cotizadas
# --- BLOQUE 26: GRÁFICO COMPARATIVO PYMEs VS COTIZADAS ---

# Filtrar solo sectores donde hay tanto PYME como cotizada
sectores_comunes = df_total.groupby('sector')['tipo'].nunique()
sectores_validos = sectores_comunes[sectores_comunes == 2].index.tolist()
df_comparativa = df_total[df_total['sector'].isin(sectores_validos)]

fig_comp = px.bar(
    df_comparativa,
    x='sector',
    y='margen_bruto_pct',
    color='tipo',
    barmode='group',
    color_discrete_map={'PYME': '#2563eb', 'Cotizada': '#d97706'},
    hover_data=['nombre'],
    text='margen_bruto_pct',
    title='Margen Bruto — PYMEs vs Empresas Cotizadas del mismo sector',
    labels={
        'margen_bruto_pct': 'Margen bruto (%)',
        'sector': 'Sector',
        'tipo': 'Tipo de empresa'
    }
)

fig_comp.update_traces(texttemplate='%{text:.1f}%', textposition='outside')
fig_comp.update_layout(height=520, yaxis_title='Margen bruto (%)')

fig_comp.write_html('comparativa_pymes_cotizadas.html')
print('✅ Gráfico guardado como comparativa_pymes_cotizadas.html')
print('   Ábrelo desde el panel Output de Kaggle para verlo interactivo')

## 20. Comparativa sectorial — Valoraciones orientativas
# --- BLOQUE 27: VALORACIONES ORIENTATIVAS POR COMPARABLES ---

# --- PARÁMETROS ---
DESCUENTO_LIQUIDEZ = 0.30   # 30% de descuento por no cotizar en bolsa

# --- PER MEDIO POR SECTOR DESDE LAS COTIZADAS ---
per_sector = df_cotizadas.groupby('sector')['per'].mean().to_dict()

# --- ESTIMACIÓN DE BENEFICIO NETO POR PYME ---
# Aproximación: beneficio neto ≈ margen bruto * 0.40 * facturación
df['beneficio_estimado'] = (
    df['margen_bruto_pct'] / 100 * 0.40 * df['facturacion']
).round(0)

# --- VALORACIÓN POR EMPRESA ---
valoraciones = []
for _, row in df.iterrows():
    per = per_sector.get(row['sector'], 15)  # 15x por defecto si no hay comparable
    valor_bruto     = row['beneficio_estimado'] * per
    valor_ajustado  = valor_bruto * (1 - DESCUENTO_LIQUIDEZ)
    valoraciones.append({
        'nombre':             row['nombre'],
        'sector':             row['sector'],
        'facturacion':        row['facturacion'],
        'beneficio_estimado': row['beneficio_estimado'],
        'per_sector':         round(per, 1),
        'valor_bruto':        round(valor_bruto, 0),
        'descuento_liquidez': f'{DESCUENTO_LIQUIDEZ * 100:.0f}%',
        'valoracion_ajustada': round(valor_ajustado, 0)
    })

df_valoraciones = pd.DataFrame(valoraciones)
df_valoraciones = df_valoraciones.sort_values(
    'valoracion_ajustada', ascending=False)

print('=== VALORACIONES ORIENTATIVAS ===')
print(df_valoraciones[['nombre', 'facturacion', 'beneficio_estimado',
                        'per_sector', 'valoracion_ajustada']].to_string())

## 21. Exportación — Excel 4 hojas
# --- BLOQUE 28: EXPORTACIÓN A EXCEL CON 4 HOJAS ---

# !pip install openpyxl -q

nombre_archivo = 'analizador_pymes_v02.xlsx'

with pd.ExcelWriter(nombre_archivo, engine='openpyxl') as writer:

    # Hoja 1: Ranking final v0.2
    cols_ranking = ['nombre', 'sector', 'facturacion', 'margen_bruto_pct',
                    'ratio_endeudamiento', 'años_activo',
                    'score_estadistico', 'calidad_margen', 'riesgo_deuda']
    ranking_v2[cols_ranking].to_excel(
        writer, sheet_name='Ranking v0.2', index=True)

    # Hoja 2: Estadística descriptiva del conjunto
    cols_stats = ['margen_bruto_pct', 'ratio_endeudamiento',
                  'fact_por_empleado', 'años_activo', 'score_estadistico']
    df[cols_stats].describe().round(2).to_excel(
        writer, sheet_name='Estadística')

    # Hoja 3: Comparativa sectorial
    stats_sector.to_excel(writer, sheet_name='Por sector')

    # Hoja 4: Valoraciones orientativas
    df_valoraciones.to_excel(writer, sheet_name='Valoraciones', index=False)

print(f'✅ Excel guardado: {nombre_archivo}')
print('   Hojas: Ranking v0.2 · Estadística · Por sector · Valoraciones')

# Analizador de PYMEs v0.3 — Mes 3
## 1. Datos históricos — 9 empresas, 4 años (2022-2025)

# --- BLOQUE 29: DATASET TEMPORAL DE LAS 9 EMPRESAS ---

import pandas as pd
import numpy as np

# Dataset temporal — 3 años x 9 empresas
# Cada empresa tiene datos de 2022, 2023 y 2024
datos_temporales = {
    'nombre': ['Ferretería García']*3 + ['Bar El Rincón']*3 +
              ['Peluquería Ana']*3 + ['Tienda Moda Sol']*3 +
              ['Gestoría Pérez']*3 + ['Clínica Dental Martínez']*3 +
              ['Academia Idiomas Sol']*3 + ['Clínica Dental García']*3 +
              ['Academia Idiomas English House']*3,
    'año': [2022, 2023, 2024] * 9,
    'facturacion': [
        295000, 308000, 320000,  # Ferretería García — crecimiento estable
        165000, 172000, 180000,  # Bar El Rincón — crecimiento lento
        85000,  90000,  95000,   # Peluquería Ana — crecimiento lento
        195000, 202000, 210000,  # Tienda Moda Sol — estable
        125000, 133000, 140000,  # Gestoría Pérez — crecimiento estable
        255000, 268000, 280000,  # Clínica Dental Martínez — crecimiento bueno
        145000, 152000, 160000,  # Academia Idiomas Sol — crecimiento lento
        270000, 283000, 295000,  # Clínica Dental García — crecimiento bueno
        138000, 146000, 155000,  # Academia English House — crecimiento bueno
    ],
    'margen_bruto_pct': [
        32.5, 33.1, 34.4,  # Ferretería García
        46.8, 47.0, 47.2,  # Bar El Rincón
        59.2, 59.5, 60.0,  # Peluquería Ana
        32.5, 32.9, 33.3,  # Tienda Moda Sol
        66.5, 67.2, 67.9,  # Gestoría Pérez
        59.0, 59.5, 60.0,  # Clínica Dental Martínez
        69.5, 69.7, 70.0,  # Academia Idiomas Sol
        59.5, 59.8, 60.0,  # Clínica Dental García
        49.5, 49.7, 50.0,  # Academia English House
    ]
}

df_temporal = pd.DataFrame(datos_temporales)

# Convertir año a formato fecha — necesario para series temporales
df_temporal['fecha'] = pd.to_datetime(df_temporal['año'].astype(str) + '-01-01')
df_temporal = df_temporal.set_index('fecha')

print('Dataset temporal creado:')
print(df_temporal.head(12))
print(f'\nEmpresas: {df_temporal["nombre"].nunique()}')
print(f'Años: {df_temporal["año"].unique()}')

## 2. Operaciones con DatetimeIndex
# --- BLOQUE 30: OPERACIONES CON DATETIMEINDEX ---

# --- FILTRAR POR EMPRESA ---
# Seleccionar todos los datos de una empresa
ferreteria = df_temporal[df_temporal['nombre'] == 'Ferretería García']
print('Datos de Ferretería García:')
print(ferreteria[['año', 'facturacion', 'margen_bruto_pct']])

# --- FILTRAR POR FECHA ---
# Solo datos de 2023 en adelante
desde_2023 = df_temporal.loc['2023':]
print('\nDatos desde 2023:')
print(desde_2023.groupby('nombre')['facturacion'].sum())

# --- CRECIMIENTO ANUAL POR EMPRESA ---
# pct_change() calcula el cambio porcentual respecto al año anterior
crecimiento = df_temporal.groupby('nombre')['facturacion'].pct_change() * 100
df_temporal['crecimiento_pct'] = crecimiento.round(1)

print('\nCrecimiento anual por empresa:')
print(df_temporal[df_temporal['año'] == 2024][['nombre', 'facturacion', 'crecimiento_pct']]
      .sort_values('crecimiento_pct', ascending=False).to_string())

# --- MEDIA MÓVIL DE FACTURACIÓN ---
# rolling(2) calcula la media de los 2 años anteriores
df_temporal['media_movil'] = (
    df_temporal.groupby('nombre')['facturacion']
    .transform(lambda x: x.rolling(2, min_periods=1).mean())
).round(0)

print('\nMedia móvil de facturación (2 años):')
print(df_temporal[['nombre', 'año', 'facturacion', 'media_movil']].tail(9).to_string())

## 3. Visualización temporal — evolución y tendencias
# --- BLOQUE 31: VISUALIZACIÓN TEMPORAL POR EMPRESA ---

import matplotlib.pyplot as plt

# --- GRÁFICO DE EVOLUCIÓN DE FACTURACIÓN ---
fig, axes = plt.subplots(3, 3, figsize=(15, 10))
fig.suptitle('Evolución de Facturación 2022-2024 — 9 PYMEs',
             fontsize=14, fontweight='bold')

empresas = df_temporal['nombre'].unique()

for ax, empresa in zip(axes.flat, empresas):
    datos = df_temporal[df_temporal['nombre'] == empresa]
    ax.plot(datos['año'], datos['facturacion'],
            marker='o', linewidth=2, color='#2563eb')
    ax.fill_between(datos['año'], datos['facturacion'],
                    alpha=0.1, color='#2563eb')
    ax.set_title(empresa.split(' ')[0], fontsize=9, fontweight='bold')
    ax.set_ylabel('€', fontsize=8)
    ax.tick_params(labelsize=7)
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('evolucion_facturacion.png', dpi=150, bbox_inches='tight')
plt.show()
print('Gráfico guardado')

# --- GRÁFICO DE EVOLUCIÓN DE MÁRGENES ---
fig2, ax2 = plt.subplots(figsize=(13, 6))

for empresa in empresas:
    datos = df_temporal[df_temporal['nombre'] == empresa]
    ax2.plot(datos['año'], datos['margen_bruto_pct'],
             marker='o', label=empresa.split(' ')[0], linewidth=1.5)

ax2.set_title('Evolución del Margen Bruto 2022-2024', fontsize=13, fontweight='bold')
ax2.set_xlabel('Año')
ax2.set_ylabel('Margen bruto (%)')
ax2.legend(fontsize=8, loc='center left', bbox_to_anchor=(1, 0.5))
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('evolucion_margenes.png', dpi=150, bbox_inches='tight')
plt.show()

## 4. Análisis de crecimiento y CAGR
# --- BLOQUE 32: RANKING DE CRECIMIENTO Y CAGR ---

# --- CAGR (Compound Annual Growth Rate) ---
# Crecimiento compuesto anual: tasa que, aplicada cada año,
# lleva del valor inicial al valor final

resumen_temporal = []
for empresa in df_temporal['nombre'].unique():
    datos = df_temporal[df_temporal['nombre'] == empresa].sort_values('año')
    facturacion_inicio = datos.iloc[0]['facturacion']
    facturacion_final  = datos.iloc[-1]['facturacion']
    n_años = len(datos) - 1
    cagr = ((facturacion_final / facturacion_inicio) ** (1/n_años) - 1) * 100
    margen_actual = datos.iloc[-1]['margen_bruto_pct']
    resumen_temporal.append({
        'nombre':           empresa,
        'facturacion_2024': facturacion_final,
        'cagr_pct':         round(cagr, 1),
        'margen_actual':    margen_actual,
        'calidad':          round(cagr * margen_actual / 100, 2)
    })

df_crecimiento = pd.DataFrame(resumen_temporal)
df_crecimiento = df_crecimiento.sort_values('calidad', ascending=False)
df_crecimiento.index = range(1, len(df_crecimiento) + 1)

print('=== RANKING DE CALIDAD DE CRECIMIENTO ===')
print(df_crecimiento.to_string())
print('\nMejor crecimiento:', df_crecimiento.iloc[0]['nombre'])

## 4. Proyección básica a 2025
# --- BLOQUE 33: PROYECCIÓN SIMPLE A 2025 ---

# --- PROYECCIÓN SIMPLE BASADA EN CAGR ---
# Usamos el CAGR de cada empresa para estimar 2025

proyeccion_2025 = []
for _, row in df_crecimiento.iterrows():
    empresa = row['nombre']
    datos = df_temporal[df_temporal['nombre'] == empresa]
    facturacion_2024 = datos[datos['año'] == 2024].iloc[0]['facturacion']
    margen_2024 = datos[datos['año'] == 2024].iloc[0]['margen_bruto_pct']
    cagr = row['cagr_pct'] / 100
    proyeccion_2025.append({
        'nombre':           empresa,
        'año':              2025,
        'facturacion':      round(facturacion_2024 * (1 + cagr), 0),
        'margen_bruto_pct': round(margen_2024 + 0.2, 1),  # mejora leve
        'crecimiento_pct':  round(cagr * 100, 1),
        'media_movil':      None
    })

df_2025 = pd.DataFrame(proyeccion_2025)
df_2025['fecha'] = pd.to_datetime('2025-01-01')
df_2025 = df_2025.set_index('fecha')

# Concatenar con el dataset histórico
df_completo = pd.concat([df_temporal, df_2025])
print('Dataset completo 2022-2025:')
print(df_completo.groupby('año')['facturacion'].sum())
# Out:
#                               nombre      sector  facturacion  coste_ventas  \
# 0                  Ferretería García  Ferretería       320000        210000
# 1                      Bar El Rincón  Hostelería       180000         95000
# 2                     Peluquería Ana  Peluquería        95000         38000
# 3                    Tienda Moda Sol        Moda       210000        140000
# 4                     Gestoría Pérez    Gestoría       140000         45000
# 5            Clínica Dental Martínez       Salud       280000         84000
# 6               Academia Idiomas Sol   Educación       160000         48000
# 7              Clínica Dental García       Salud       295000        118000
# 8  Academia de Idiomas English House   Educación       155000         77500
#
#    empleados  deuda  activo_total  año_fundacion
# 0          5  45000        180000           2008
# 1          4  12000         85000           2015
# 2          2   8000         40000           2019
# 3          3  35000        120000           2012
# 4          3   5000         70000           2006
# 5          6  90000        220000           2014
# 6          5  15000         75000           2016
# 7          6  95000        230000           2013
# 8          5  14000         72000           2017
#
# Número de empresas analizadas: 9
#                               nombre  margen_bruto_pct  ratio_endeudamiento  \
# 0                  Ferretería García              34.4                 0.25
# 1                      Bar El Rincón              47.2                 0.14
# 2                     Peluquería Ana              60.0                 0.20
# 3                    Tienda Moda Sol              33.3                 0.29
# 4                     Gestoría Pérez              67.9                 0.07
# 5            Clínica Dental Martínez              70.0                 0.41
# 6               Academia Idiomas Sol              70.0                 0.20
# 7              Clínica Dental García              60.0                 0.41
# 8  Academia de Idiomas English House              50.0                 0.19
#
#    fact_por_empleado  años_activo
# 0            64000.0           18
# 1            45000.0           11
# 2            47500.0            7
# 3            70000.0           14
# 4            46667.0           20
# 5            46667.0           12
# 6            32000.0           10
# 7            49167.0           13
# 8            31000.0            9
# Empresas con bajo endeudamiento:
#                               nombre  ratio_endeudamiento
# 0                  Ferretería García                 0.25
# 1                      Bar El Rincón                 0.14
# 2                     Peluquería Ana                 0.20
# 3                    Tienda Moda Sol                 0.29
# 4                     Gestoría Pérez                 0.07
# 6               Academia Idiomas Sol                 0.20
# 8  Academia de Idiomas English House                 0.19
#
# Mejores candidatas para inversión:
#                               nombre  margen_bruto_pct  ratio_endeudamiento
# 0                  Ferretería García              34.4                 0.25
# 1                      Bar El Rincón              47.2                 0.14
# 2                     Peluquería Ana              60.0                 0.20
# 3                    Tienda Moda Sol              33.3                 0.29
# 4                     Gestoría Pérez              67.9                 0.07
# 6               Academia Idiomas Sol              70.0                 0.20
# 8  Academia de Idiomas English House              50.0                 0.19
#
# Ranking por margen bruto:
#                               nombre  margen_bruto_pct
# 6               Academia Idiomas Sol              70.0
# 5            Clínica Dental Martínez              70.0
# 4                     Gestoría Pérez              67.9
# 7              Clínica Dental García              60.0
# 2                     Peluquería Ana              60.0
# 8  Academia de Idiomas English House              50.0
# 1                      Bar El Rincón              47.2
# 0                  Ferretería García              34.4
# 3                    Tienda Moda Sol              33.3
#
# Empresas sobre la media del grupo:
# ['Peluquería Ana', 'Gestoría Pérez', 'Clínica Dental Martínez', 'Academia Idiomas Sol', 'Clínica Dental García']
#                               nombre calidad_margen riesgo_deuda  años_activo  \
# 0                  Ferretería García           Alto         Bajo           18
# 1                      Bar El Rincón           Alto         Bajo           11
# 2                     Peluquería Ana           Alto         Bajo            7
# 3                    Tienda Moda Sol           Alto        Medio           14
# 4                     Gestoría Pérez           Alto         Bajo           20
# 5            Clínica Dental Martínez           Alto        Medio           12
# 6               Academia Idiomas Sol           Alto         Bajo           10
# 7              Clínica Dental García           Alto        Medio           13
# 8  Academia de Idiomas English House           Alto         Bajo            9
#
#    puntuacion_total
# 0                 8
# 1                 8
# 2                 8
# 3                 7
# 4                 8
# 5                 7
# 6                 8
# 7                 7
# 8                 8
# =======================================================
# RANKING DE OPORTUNIDADES DE INVERSIÓN EN PYMEs
# =======================================================
#                               nombre      sector  facturacion  margen_bruto_pct  ratio_endeudamiento  años_activo  puntuacion_total calidad_margen riesgo_deuda
# 1                  Ferretería García  Ferretería       320000              34.4                 0.25           18                 8           Alto         Bajo
# 2                      Bar El Rincón  Hostelería       180000              47.2                 0.14           11                 8           Alto         Bajo
# 3                     Peluquería Ana  Peluquería        95000              60.0                 0.20            7                 8           Alto         Bajo
# 4                     Gestoría Pérez    Gestoría       140000              67.9                 0.07           20                 8           Alto         Bajo
# 5               Academia Idiomas Sol   Educación       160000              70.0                 0.20           10                 8           Alto         Bajo
# 6  Academia de Idiomas English House   Educación       155000              50.0                 0.19            9                 8           Alto         Bajo
# 7                    Tienda Moda Sol        Moda       210000              33.3                 0.29           14                 7           Alto        Medio
# 8            Clínica Dental Martínez       Salud       280000              70.0                 0.41           12                 7           Alto        Medio
# 9              Clínica Dental García       Salud       295000              60.0                 0.41           13                 7           Alto        Medio
#
# Mejor oportunidad: Ferretería García
# Mayor riesgo:      Clínica Dental García
# === RESUMEN ESTADÍSTICO ===
#        margen_bruto_pct  ratio_endeudamiento  fact_por_empleado
# count          9.000000             9.000000           9.000000
# mean          54.755556             0.240000       48000.111111
# std           14.348180             0.114564       12743.457473
# min           33.300000             0.070000       31000.000000
# 25%           47.200000             0.190000       45000.000000
# 50%           60.000000             0.200000       46667.000000
# 75%           67.900000             0.290000       49167.000000
# max           70.000000             0.410000       70000.000000
#
# === MEDIAS DEL GRUPO ===
# Margen bruto medio: 54.8 %
# Endeudamiento medio: 0.24
# Facturación por empleado media: 48000.0 €
#
# === DESTACADOS ===
# Mejor margen: Clínica Dental Martínez
# Peor margen: Tienda Moda Sol
# Menor riesgo de deuda: Gestoría Pérez
#
# === MEDIAS POR SECTOR ===
#             margen_bruto_pct  ratio_endeudamiento
# sector
# Educación               60.0                 0.20
# Ferretería              34.4                 0.25
# Gestoría                67.9                 0.07
# Hostelería              47.2                 0.14
# Moda                    33.3                 0.29
# Peluquería              60.0                 0.20
# Salud                   65.0                 0.41
#
# Sectores ordenados por margen (mejor a peor):
#             margen_bruto_pct  ratio_endeudamiento
# sector
# Gestoría                67.9                 0.07
# Salud                   65.0                 0.41
# Educación               60.0                 0.20
# Peluquería              60.0                 0.20
# Hostelería              47.2                 0.14
# Ferretería              34.4                 0.25
# Moda                    33.3                 0.29
# === ANALIZADOR DE PYMEs v0.1 — RESUMEN ===
# Empresas analizadas: 9
# Sectores cubiertos: 7
# Mejor oportunidad: Ferretería García (8 puntos)
# Mayor riesgo: Clínica Dental García (7 puntos)
# Margen bruto medio del grupo: 54.8%
# Sector más rentable: Gestoría
# Archivo guardado: ranking_pymes_v01.xlsx
# Hojas: Ranking, Datos
# === RESUMEN ESTADÍSTICO DEL CONJUNTO ===
#        margen_bruto_pct  ratio_endeudamiento  fact_por_empleado  años_activo
# count              9.00                 9.00               9.00         9.00
# mean              54.76                 0.24           48000.11        12.67
# std               14.35                 0.11           12743.46         4.18
# min               33.30                 0.07           31000.00         7.00
# 25%               47.20                 0.19           45000.00        10.00
# 50%               60.00                 0.20           46667.00        12.00
# 75%               67.90                 0.29           49167.00        14.00
# max               70.00                 0.41           70000.00        20.00
#
# === VALORES CLAVE ===
# Margen bruto medio: 54.8 %
# Mediana de margen:  60.0 %
# Desviación estándar: 14.3 %
#
# Outliers por margen bruto:
# Empty DataFrame
# Columns: [nombre, margen_bruto_pct]
# Index: []
# === MATRIZ DE CORRELACIÓN ===
#                      facturacion  margen_bruto_pct  ratio_endeudamiento  \
# facturacion                 1.00             -0.28                 0.72
# margen_bruto_pct           -0.28              1.00                 0.01
# ratio_endeudamiento         0.72              0.01                 1.00
# fact_por_empleado           0.47             -0.66                 0.28
# años_activo                 0.42             -0.19                -0.13
# puntuacion_total           -0.56              0.02                -0.85
#
#                      fact_por_empleado  años_activo  puntuacion_total
# facturacion                       0.47         0.42             -0.56
# margen_bruto_pct                 -0.66        -0.19              0.02
# ratio_endeudamiento               0.28        -0.13             -0.85
# fact_por_empleado                 1.00         0.51             -0.43
# años_activo                       0.51         1.00             -0.06
# puntuacion_total                 -0.43        -0.06              1.00
#
# Correlación de cada variable con la puntuación total:
# puntuacion_total       1.00
# margen_bruto_pct       0.02
# años_activo           -0.06
# fact_por_empleado     -0.43
# facturacion           -0.56
# ratio_endeudamiento   -0.85
# Name: puntuacion_total, dtype: float64
# facturacion tiene correlación negativa fuerte con puntuación: -0.56
# ratio_endeudamiento tiene correlación negativa fuerte con puntuación: -0.85
# === ANÁLISIS ESTADÍSTICO POR SECTOR ===
#             media  mediana  desviacion  minimo  maximo  empresas
# sector
# Educación    60.0     60.0       14.14    50.0    70.0         2
# Ferretería   34.4     34.4         NaN    34.4    34.4         1
# Gestoría     67.9     67.9         NaN    67.9    67.9         1
# Hostelería   47.2     47.2         NaN    47.2    47.2         1
# Moda         33.3     33.3         NaN    33.3    33.3         1
# Peluquería   60.0     60.0         NaN    60.0    60.0         1
# Salud        65.0     65.0        7.07    60.0    70.0         2
#
# Sectores ordenados por margen medio:
#             media  mediana  desviacion  minimo  maximo  empresas
# sector
# Gestoría     67.9     67.9         NaN    67.9    67.9         1
# Salud        65.0     65.0        7.07    60.0    70.0         2
# Educación    60.0     60.0       14.14    50.0    70.0         2
# Peluquería   60.0     60.0         NaN    60.0    60.0         1
# Hostelería   47.2     47.2         NaN    47.2    47.2         1
# Ferretería   34.4     34.4         NaN    34.4    34.4         1
# Moda         33.3     33.3         NaN    33.3    33.3         1
#
# Sectores por variabilidad (std):
#             desviacion
# sector
# Educación        14.14
# Salud             7.07
# Ferretería         NaN
# Gestoría           NaN
# Hostelería         NaN
# Moda               NaN
# Peluquería         NaN
# === RANKING v0.2 — SCORING ESTADÍSTICO ===
#                               nombre  pct_margen  pct_deuda  pct_antiguedad  \
# 1                     Gestoría Pérez        0.78       0.89            1.00
# 2               Academia Idiomas Sol        0.94       0.50            0.33
# 3            Clínica Dental Martínez        0.94       0.06            0.56
# 4                      Bar El Rincón        0.33       0.78            0.44
# 5                     Peluquería Ana        0.61       0.50            0.11
# 6  Academia de Idiomas English House        0.44       0.67            0.22
# 7              Clínica Dental García        0.61       0.06            0.67
# 8                  Ferretería García        0.22       0.33            0.89
# 9                    Tienda Moda Sol        0.11       0.22            0.78
#
#    score_estadistico
# 1              0.857
# 2              0.686
# 3              0.600
# 4              0.487
# 5              0.477
# 6              0.465
# 7              0.457
# 8              0.387
# 9              0.277
#
# Mejor oportunidad: Gestoría Pérez
# =======================================================
# RANKING v0.2 — SCORING ESTADÍSTICO POR PERCENTILES
# =======================================================
#                               nombre      sector  pct_margen  pct_deuda  pct_antiguedad  score_estadistico
# 1                     Gestoría Pérez    Gestoría        0.78       0.89            1.00              0.857
# 2               Academia Idiomas Sol   Educación        0.94       0.50            0.33              0.686
# 3            Clínica Dental Martínez       Salud        0.94       0.06            0.56              0.600
# 4                      Bar El Rincón  Hostelería        0.33       0.78            0.44              0.487
# 5                     Peluquería Ana  Peluquería        0.61       0.50            0.11              0.477
# 6  Academia de Idiomas English House   Educación        0.44       0.67            0.22              0.465
# 7              Clínica Dental García       Salud        0.61       0.06            0.67              0.457
# 8                  Ferretería García  Ferretería        0.22       0.33            0.89              0.387
# 9                    Tienda Moda Sol        Moda        0.11       0.22            0.78              0.277
#
# Mejor oportunidad: Gestoría Pérez — score: 0.857
# Mayor riesgo:      Tienda Moda Sol — score: 0.277
# ==== ANALIZADOR DE PYMEs v0.2 — RESUMEN ====
# Empresas analizadas: 9
# Sectores cubiertos: 7
# Correlación margen-score: 0.82
# Mejor oportunidad: Gestoría Pérez (score: 0.857)
# Mayor riesgo: Tienda Moda Sol (score: 0.277)
# Sector con mejor margen medio: Gestoría
# Gráfico guardado como grafico_ranking_pymes.png
# Gráfico guardado como scatter_margen_deuda.png
# ✅ Histogramas guardados como histogramas_pymes.png
# ✅ Gráfico guardado como comparativa_sectorial.png
# ✅ Dashboard guardado como dashboard_pymes_v02.png
# ✅ Gráfico guardado como ranking_interactivo.html
#    Ábrelo desde el panel Output de Kaggle para verlo interactivo
# ✅ Gráfico guardado como scatter_interactivo.html
#    Ábrelo desde el panel Output de Kaggle para verlo interactivo
# ✅ Gráfico guardado como radar_empresas.html
#    Comparando: Gestoría Pérez vs Academia Idiomas Sol
# ✅ Dashboard guardado como dashboard_interactivo.html
#    Ábrelo desde el panel Output de Kaggle para verlo interactivo
# /tmp/ipykernel_55/3962881438.py:645: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ✓ MCD descargado
# ✓ ITX.MC descargado
# ✓ FRE.DE descargado
# ✓ PSO descargado
# ✓ FAST descargado
# ✓ HRB descargado
#
# Datos de cotizadas:
#                             nombre      sector  margen_bruto_pct  \
# 0           McDonald's Corporation  Hostelería              57.4
# 1  INDUSTRIA DE DISE...O TEXTIL S.        Moda              56.3
# 2  Fresenius SE & Co. KGaA       I       Salud              24.9
# 3                     Pearson, Plc   Educación              52.0
# 4                 Fastenal Company  Ferretería              44.9
# 5                  H&R Block, Inc.    Gestoría              44.2
#
#    margen_operativo   per
# 0              45.1  25.8
# 1              18.0  27.2
# 2              10.8  16.1
# 3              14.0  21.1
# 4              20.3  40.5
# 5            -150.3   7.5
# DataFrame combinado:
#         sector      tipo  n_empresas
# 0    Educación  Cotizada           1
# 1    Educación      PYME           2
# 2   Ferretería  Cotizada           1
# 3   Ferretería      PYME           1
# 4     Gestoría  Cotizada           1
# 5     Gestoría      PYME           1
# 6   Hostelería  Cotizada           1
# 7   Hostelería      PYME           1
# 8         Moda  Cotizada           1
# 9         Moda      PYME           1
# 10  Peluquería      PYME           1
# 11       Salud  Cotizada           1
# 12       Salud      PYME           2
#
# Margen bruto medio — PYMEs vs cotizadas:
# tipo        Cotizada  PYME
# sector
# Educación       52.0  60.0
# Ferretería      44.9  34.4
# Gestoría        44.2  67.9
# Hostelería      57.4  47.2
# Moda            56.3  33.3
# Peluquería       NaN  60.0
# Salud           24.9  65.0
# ✅ Gráfico guardado como comparativa_pymes_cotizadas.html
#    Ábrelo desde el panel Output de Kaggle para verlo interactivo
# === VALORACIONES ORIENTATIVAS ===
#                               nombre  facturacion  beneficio_estimado  per_sector  valoracion_ajustada
# 0                  Ferretería García       320000             44032.0        40.5            1248307.0
# 5            Clínica Dental Martínez       280000             78400.0        16.1             883568.0
# 7              Clínica Dental García       295000             70800.0        16.1             797916.0
# 6               Academia Idiomas Sol       160000             44800.0        21.1             661696.0
# 1                      Bar El Rincón       180000             33984.0        25.8             613751.0
# 3                    Tienda Moda Sol       210000             27972.0        27.2             532587.0
# 8  Academia de Idiomas English House       155000             31000.0        21.1             457870.0
# 2                     Peluquería Ana        95000             22800.0        15.0             239400.0
# 4                     Gestoría Pérez       140000             38024.0         7.5             199626.0
# /tmp/ipykernel_55/3962881438.py:744: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# ✅ Excel guardado: analizador_pymes_v02.xlsx
#    Hojas: Ranking v0.2 · Estadística · Por sector · Valoraciones
# Dataset temporal creado:
#                        nombre   año  facturacion  margen_bruto_pct
# fecha
# 2022-01-01  Ferretería García  2022       295000              32.5
# 2023-01-01  Ferretería García  2023       308000              33.1
# 2024-01-01  Ferretería García  2024       320000              34.4
# 2022-01-01      Bar El Rincón  2022       165000              46.8
# 2023-01-01      Bar El Rincón  2023       172000              47.0
# 2024-01-01      Bar El Rincón  2024       180000              47.2
# 2022-01-01     Peluquería Ana  2022        85000              59.2
# 2023-01-01     Peluquería Ana  2023        90000              59.5
# 2024-01-01     Peluquería Ana  2024        95000              60.0
# 2022-01-01    Tienda Moda Sol  2022       195000              32.5
# 2023-01-01    Tienda Moda Sol  2023       202000              32.9
# 2024-01-01    Tienda Moda Sol  2024       210000              33.3
#
# Empresas: 9
# Años: [2022 2023 2024]
# Datos de Ferretería García:
#              año  facturacion  margen_bruto_pct
# fecha
# 2022-01-01  2022       295000              32.5
# 2023-01-01  2023       308000              33.1
# 2024-01-01  2024       320000              34.4
#
# Datos desde 2023:
# nombre
# Academia Idiomas English House    301000
# Academia Idiomas Sol              312000
# Bar El Rincón                     352000
# Clínica Dental García             578000
# Clínica Dental Martínez           548000
# Ferretería García                 628000
# Gestoría Pérez                    273000
# Peluquería Ana                    185000
# Tienda Moda Sol                   412000
# Name: facturacion, dtype: int64
#
# Crecimiento anual por empresa:
#                                     nombre  facturacion  crecimiento_pct
# fecha
# 2024-01-01  Academia Idiomas English House       155000              6.2
# 2024-01-01                  Peluquería Ana        95000              5.6
# 2024-01-01            Academia Idiomas Sol       160000              5.3
# 2024-01-01                  Gestoría Pérez       140000              5.3
# 2024-01-01                   Bar El Rincón       180000              4.7
# 2024-01-01         Clínica Dental Martínez       280000              4.5
# 2024-01-01           Clínica Dental García       295000              4.2
# 2024-01-01                 Tienda Moda Sol       210000              4.0
# 2024-01-01               Ferretería García       320000              3.9
#
# Media móvil de facturación (2 años):
#                                     nombre   año  facturacion  media_movil
# fecha
# 2022-01-01            Academia Idiomas Sol  2022       145000     145000.0
# 2023-01-01            Academia Idiomas Sol  2023       152000     148500.0
# 2024-01-01            Academia Idiomas Sol  2024       160000     156000.0
# 2022-01-01           Clínica Dental García  2022       270000     270000.0
# 2023-01-01           Clínica Dental García  2023       283000     276500.0
# 2024-01-01           Clínica Dental García  2024       295000     289000.0
# 2022-01-01  Academia Idiomas English House  2022       138000     138000.0
# 2023-01-01  Academia Idiomas English House  2023       146000     142000.0
# 2024-01-01  Academia Idiomas English House  2024       155000     150500.0
# Gráfico guardado
# === RANKING DE CALIDAD DE CRECIMIENTO ===
#                            nombre  facturacion_2024  cagr_pct  margen_actual  calidad
# 1                  Gestoría Pérez            140000       5.8           67.9     3.96
# 2            Academia Idiomas Sol            160000       5.0           70.0     3.53
# 3                  Peluquería Ana             95000       5.7           60.0     3.43
# 4  Academia Idiomas English House            155000       6.0           50.0     2.99
# 5         Clínica Dental Martínez            280000       4.8           60.0     2.87
# 6           Clínica Dental García            295000       4.5           60.0     2.72
# 7                   Bar El Rincón            180000       4.4           47.2     2.10
# 8               Ferretería García            320000       4.2           34.4     1.43
# 9                 Tienda Moda Sol            210000       3.8           33.3     1.26
#
# Mejor crecimiento: Gestoría Pérez
# Dataset completo 2022-2025:
# año
# 2022    1673000.0
# 2023    1754000.0
# 2024    1835000.0
# 2025    1921890.0
# Name: facturacion, dtype: float64
# /tmp/ipykernel_55/3962881438.py:1052: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
